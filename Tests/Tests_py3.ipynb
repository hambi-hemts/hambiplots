# %%
import hambiplots.plots_py3 as hp

# %%
hp.

# %%
####### external modules #######
from numpy import *

######## PLOTS ###########
from matplotlib import *
from matplotlib.pyplot import *
import matplotlib as mpl

from mpltools import layout
from mpltools import color
color.cycle_cmap(10, cmap='pink')

# %matplotlib inline

####### my modules #######
import hambiplots.plots_py3 as hp
reload(hp)

hp.set_rcParams()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-81a803a5202c> in <module>()
#      17 reload(hp)
#      18
# ---> 19 hp.set_rcParams()
#
# AttributeError: 'module' object has no attribute 'set_rcParams'

# %%
def make_plot():
    figure()
    grid(True)
    x = linspace(0, 10, 100)
    plot(x, x**2, label = r'$f(x) = x^2$')
    xlabel('x-label')
    ylabel('y-label')
    title('the title')
    legend(loc = 'best')

# %%
make_plot()

# %%
make_plot()
hp.set_format('png')

# %%
make_plot()
hp.save('testo.pdf', dpi = 240)
# Out:
# Changed output format to  pdf

# %%
make_plot()
hp.set_format('png')
hp.save('chicken')

# %%
# !ipython nbconvert Tests.ipynb
# Out:
# [NbConvertApp] Using existing profile dir: u'C:\\Users\\Anna\\.ipython\\profile_default'
# [NbConvertApp] Converting notebook Tests.ipynb to html
# [NbConvertApp] Support files will be in Tests_files\
# [NbConvertApp] Loaded template full.tpl
# [NbConvertApp] Writing 276703 bytes to Tests.html
